# %%
import os
import numpy as np
import csv
import matplotlib.pyplot as plt
from libsvm.svmutil import *

# %% [markdown]
# # SVM Task-1

# %% [markdown]
# ## MNIST Reading

# %% [markdown]
# X_train.csv is a $5000 \times 784 $matrix. Every row corresponds to a $28 \times 28 $gray-scale image. <br>
# Y_train.csv is a $5000 \times 1 $matrix, which records the class of the training samples.<br>

# %%
# for each row in X_train.csv is an image
def load_X_data(file): 
    X=[]
    with open(file, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            X.append(np.array(row))
        X = np.asarray(X, dtype=np.float32)
    return X

# 5000 class category
def load_y_data(file):
    y=[]
    with open(file, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            y.append(row[0])
        y = np.asarray(y, dtype=int)
    return y

# %%
train_X = load_X_data(r'data\ML_HW05\data\X_train.csv')
train_y = load_y_data(r'data\ML_HW05\data\y_train.csv')
test_X = load_X_data(r'data\ML_HW05\data\X_test.csv')
test_y = load_y_data(r'data\ML_HW05\data\y_test.csv')

# %% [markdown]
# ## API svm_train param

# %% [markdown]
# -s svm_type : set type of SVM (default 0)<br>
# &emsp;0 -- C-SVC (multi-class classification)<br>
# -t kernel_type : set type of kernel function (default 2) <br>
# &emsp;0 -- linear: u'*v<br>
# &emsp;1 -- polynomial: (gamma*u'*v + coef0)^degree<br>
# &emsp;2 -- radial basis function: exp(-gamma*|u-v|^2)<br>
# -c cost : set the parameter C of C-SVC, epsilon-SVR, and nu-SVR (default 1)<br>
# -g gamma : set gamma in kernel function (default 1/num_features)<br>
# -v n: n-fold cross validation mode <br>
# -q : quiet mode (no outputs)<br>

# %% [markdown]
# ### RBF kernel

# %% [markdown]
# $K(x,x') = exp(-\gamma ||x-x'||_{2}^{2})$

# %% [markdown]
# ### Grid Search

# %%
def grid_search_RBF(train_X, train_y):
    C = 0
    g = 0
    best_acc = 0
    RBF_kernel = '-t 2 '
    svm_type = '-s 0 '
    cross_validation = '-v 5 '
    for g in [0.001,0.01,0.1,1,10,100]:
        for C in [0.001,0.01,0.1,1,10,100]:
            cost = f'-c {C} '
            gamma = f'-g {g} '
            param = svm_type + RBF_kernel + cost + gamma + cross_validation + '-q'
            print('----------------------------------------------------------')
            print(f'Try the param with C = {C} , g = {g} ')
            acc = svm_train(train_y, train_X, param)     
            print('----------------------------------------------------------')
            
            if acc > best_acc:
                best_acc = acc
                best_C, best_g = C, g
    
    return best_C, best_g

# %%
def grid_search_polynomial(train_X, train_y):
    coe = 0
    d = 0
    g = 0
    best_acc = 0
    svm_type = '-s 0 '
    polynomial_kernel = '-t 1 '
    cross_validation = '-v 5 '
    for C in [0.001,0.01,0.1,1,10,100]:
        for g in [0.001,0.01,0.1,1,10,100]:
            for d in [0,1,2,3,4,5]:
                for coe in [0,1,2,3,4,5]:
                    cost = f'-c {C} '
                    gamma = f'-g {g} '
                    degree = f'-d {d} '
                    coef = f'-r {coe} '
                    param = svm_type + polynomial_kernel + cost + gamma + degree + coef + cross_validation + '-q'
                    
                    print('----------------------------------------------------------')
                    print(f'Try the param with C = {C} , g = {g} , degree = {d} , coef = {coe}')
                    acc = svm_train(train_y, train_X, param)     
                    print('----------------------------------------------------------')

                    if acc > best_acc:
                        best_acc = acc
                        best_C, best_g, best_d, best_coe = C, g, d, coe
    
    return  best_C, best_g, best_d, best_coe

# %%
def grid_search_linear(train_X, train_y):
    best_acc = 0
    svm_type = '-s 0 '
    polynomial_kernel = '-t 0 '
    cross_validation = '-v 5 '
    for C in [0.001,0.01,0.1,1,10,100]:
        cost = f'-c {C} '
        param = svm_type + polynomial_kernel + cost + cross_validation + '-q'
        
        print('----------------------------------------------------------')
        print(f'Try the param with C = {C}  ')
        acc = svm_train(train_y, train_X, param)     
        print('----------------------------------------------------------')

        if acc > best_acc:
            best_acc = acc
            best_C = C
    
    return best_C

# %%
linear_best_C = grid_search_linear(train_X, train_y)
# Out:
# ----------------------------------------------------------
# Try the param with C = 0.001
# Cross Validation Accuracy = 95.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01
# Cross Validation Accuracy = 96.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1
# Cross Validation Accuracy = 96.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1
# Cross Validation Accuracy = 96.26%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 10
# Cross Validation Accuracy = 96.44%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 100
# Cross Validation Accuracy = 96.36%
# ----------------------------------------------------------

# %%
poly_best_C, poly_best_g, poly_best_d, poly_best_coe = grid_search_polynomial(train_X, train_y)
# Out:
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 1 , coef = 0
# Cross Validation Accuracy = 79.22%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 1 , coef = 1
# Cross Validation Accuracy = 79.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 1 , coef = 2
# Cross Validation Accuracy = 79.5%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 1 , coef = 3
# Cross Validation Accuracy = 79.44%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 1 , coef = 4
# Cross Validation Accuracy = 79.48%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 1 , coef = 5
# Cross Validation Accuracy = 79.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 2 , coef = 0
# Cross Validation Accuracy = 45.32%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 2 , coef = 1
# Cross Validation Accuracy = 77.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 2 , coef = 2
# Cross Validation Accuracy = 78.8%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 2 , coef = 3
# Cross Validation Accuracy = 78.88%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 2 , coef = 4
# Cross Validation Accuracy = 79.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 2 , coef = 5
# Cross Validation Accuracy = 79.18%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 3 , coef = 0
# Cross Validation Accuracy = 28.28%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 3 , coef = 1
# Cross Validation Accuracy = 76.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 3 , coef = 2
# Cross Validation Accuracy = 78.2%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 3 , coef = 3
# Cross Validation Accuracy = 78.92%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 3 , coef = 4
# Cross Validation Accuracy = 82.48%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 3 , coef = 5
# Cross Validation Accuracy = 87.68%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 4 , coef = 0
# Cross Validation Accuracy = 23.58%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 4 , coef = 1
# Cross Validation Accuracy = 75.16%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 4 , coef = 2
# Cross Validation Accuracy = 77.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 4 , coef = 3
# Cross Validation Accuracy = 89.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 4 , coef = 4
# Cross Validation Accuracy = 93.24%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 4 , coef = 5
# Cross Validation Accuracy = 94.72%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 5 , coef = 0
# Cross Validation Accuracy = 22.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 5 , coef = 1
# Cross Validation Accuracy = 73.34%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 5 , coef = 2
# Cross Validation Accuracy = 88.26%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 5 , coef = 3
# Cross Validation Accuracy = 94.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 5 , coef = 4
# Cross Validation Accuracy = 95.8%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.001 , degree = 5 , coef = 5
# Cross Validation Accuracy = 96.38%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 1 , coef = 0
# Cross Validation Accuracy = 79.32%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 1 , coef = 1
# Cross Validation Accuracy = 79.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 1 , coef = 2
# Cross Validation Accuracy = 79.38%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 1 , coef = 3
# Cross Validation Accuracy = 79.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 1 , coef = 4
# Cross Validation Accuracy = 79.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 1 , coef = 5
# Cross Validation Accuracy = 79.28%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 2 , coef = 0
# Cross Validation Accuracy = 45.56%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 2 , coef = 1
# Cross Validation Accuracy = 70.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 2 , coef = 2
# Cross Validation Accuracy = 80.3%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 2 , coef = 3
# Cross Validation Accuracy = 86.14%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 2 , coef = 4
# Cross Validation Accuracy = 88.24%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 2 , coef = 5
# Cross Validation Accuracy = 89.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 3 , coef = 0
# Cross Validation Accuracy = 28.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 3 , coef = 1
# Cross Validation Accuracy = 79.78%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 3 , coef = 2
# Cross Validation Accuracy = 91.3%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 3 , coef = 3
# Cross Validation Accuracy = 94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 3 , coef = 4
# Cross Validation Accuracy = 94.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 3 , coef = 5
# Cross Validation Accuracy = 95.38%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 4 , coef = 0
# Cross Validation Accuracy = 23.72%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 4 , coef = 1
# Cross Validation Accuracy = 85.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 4 , coef = 2
# Cross Validation Accuracy = 94.68%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 4 , coef = 3
# Cross Validation Accuracy = 96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 4 , coef = 4
# Cross Validation Accuracy = 96.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 4 , coef = 5
# Cross Validation Accuracy = 97.2%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 5 , coef = 0
# Cross Validation Accuracy = 23.08%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 5 , coef = 1
# Cross Validation Accuracy = 89.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 5 , coef = 2
# Cross Validation Accuracy = 96.16%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 5 , coef = 3
# Cross Validation Accuracy = 97.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 5 , coef = 4
# Cross Validation Accuracy = 97.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.01 , degree = 5 , coef = 5
# Cross Validation Accuracy = 97.68%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 1 , coef = 0
# Cross Validation Accuracy = 89.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 1 , coef = 1
# Cross Validation Accuracy = 89.4%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 1 , coef = 2
# Cross Validation Accuracy = 89.34%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 1 , coef = 3
# Cross Validation Accuracy = 89.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 1 , coef = 4
# Cross Validation Accuracy = 89.44%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 1 , coef = 5
# Cross Validation Accuracy = 89.48%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 2 , coef = 0
# Cross Validation Accuracy = 94.72%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 2 , coef = 1
# Cross Validation Accuracy = 95.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 2 , coef = 2
# Cross Validation Accuracy = 95.8%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 2 , coef = 3
# Cross Validation Accuracy = 96.02%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 2 , coef = 4
# Cross Validation Accuracy = 96.22%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 2 , coef = 5
# Cross Validation Accuracy = 96.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 3 , coef = 0
# Cross Validation Accuracy = 96.56%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 3 , coef = 1
# Cross Validation Accuracy = 97.56%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 3 , coef = 2
# Cross Validation Accuracy = 97.68%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 3 , coef = 3
# Cross Validation Accuracy = 97.74%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 3 , coef = 4
# Cross Validation Accuracy = 97.84%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 3 , coef = 5
# Cross Validation Accuracy = 98.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 4 , coef = 0
# Cross Validation Accuracy = 96.38%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 4 , coef = 1
# Cross Validation Accuracy = 97.58%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 4 , coef = 2
# Cross Validation Accuracy = 98.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 4 , coef = 3
# Cross Validation Accuracy = 97.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 4 , coef = 4
# Cross Validation Accuracy = 98.06%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 4 , coef = 5
# Cross Validation Accuracy = 97.96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 5 , coef = 0
# Cross Validation Accuracy = 95.2%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 5 , coef = 1
# Cross Validation Accuracy = 96.92%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 5 , coef = 2
# Cross Validation Accuracy = 97.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 5 , coef = 3
# Cross Validation Accuracy = 97.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 5 , coef = 4
# Cross Validation Accuracy = 97.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 0.1 , degree = 5 , coef = 5
# Cross Validation Accuracy = 97.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 1 , coef = 0
# Cross Validation Accuracy = 95.5%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 1 , coef = 1
# Cross Validation Accuracy = 95.32%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 1 , coef = 2
# Cross Validation Accuracy = 95.34%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 1 , coef = 3
# Cross Validation Accuracy = 95.42%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 1 , coef = 4
# Cross Validation Accuracy = 95.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 1 , coef = 5
# Cross Validation Accuracy = 95.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 2 , coef = 0
# Cross Validation Accuracy = 98.02%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 2 , coef = 1
# Cross Validation Accuracy = 98.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 2 , coef = 2
# Cross Validation Accuracy = 98.14%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 2 , coef = 3
# Cross Validation Accuracy = 98.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 2 , coef = 4
# Cross Validation Accuracy = 98.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 2 , coef = 5
# Cross Validation Accuracy = 98.14%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 3 , coef = 0
# Cross Validation Accuracy = 97.66%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 3 , coef = 1
# Cross Validation Accuracy = 97.7%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 3 , coef = 2
# Cross Validation Accuracy = 97.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 3 , coef = 3
# Cross Validation Accuracy = 97.76%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 3 , coef = 4
# Cross Validation Accuracy = 97.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 3 , coef = 5
# Cross Validation Accuracy = 97.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 4 , coef = 0
# Cross Validation Accuracy = 96.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 4 , coef = 1
# Cross Validation Accuracy = 96.78%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 4 , coef = 2
# Cross Validation Accuracy = 96.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 4 , coef = 3
# Cross Validation Accuracy = 97.22%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 4 , coef = 4
# Cross Validation Accuracy = 97.16%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 4 , coef = 5
# Cross Validation Accuracy = 97.34%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 5 , coef = 0
# Cross Validation Accuracy = 95.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 5 , coef = 1
# Cross Validation Accuracy = 95.38%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 5 , coef = 2
# Cross Validation Accuracy = 95.4%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 5 , coef = 3
# Cross Validation Accuracy = 95.72%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 5 , coef = 4
# Cross Validation Accuracy = 96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 1 , degree = 5 , coef = 5
# Cross Validation Accuracy = 96.26%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 1 , coef = 0
# Cross Validation Accuracy = 96.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 1 , coef = 1
# Cross Validation Accuracy = 96.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 1 , coef = 2
# Cross Validation Accuracy = 96.96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 1 , coef = 3
# Cross Validation Accuracy = 96.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 1 , coef = 4
# Cross Validation Accuracy = 97.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 1 , coef = 5
# Cross Validation Accuracy = 97.06%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 2 , coef = 0
# Cross Validation Accuracy = 98.08%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 2 , coef = 1
# Cross Validation Accuracy = 98.06%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 2 , coef = 2
# Cross Validation Accuracy = 97.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 2 , coef = 3
# Cross Validation Accuracy = 97.84%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 2 , coef = 4
# Cross Validation Accuracy = 98.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 2 , coef = 5
# Cross Validation Accuracy = 98.3%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 3 , coef = 0
# Cross Validation Accuracy = 97.44%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 3 , coef = 1
# Cross Validation Accuracy = 97.76%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 3 , coef = 2
# Cross Validation Accuracy = 97.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 3 , coef = 3
# Cross Validation Accuracy = 97.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 3 , coef = 4
# Cross Validation Accuracy = 97.72%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 3 , coef = 5
# Cross Validation Accuracy = 97.68%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 4 , coef = 0
# Cross Validation Accuracy = 96.72%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 4 , coef = 1
# Cross Validation Accuracy = 96.62%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 4 , coef = 2
# Cross Validation Accuracy = 96.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 4 , coef = 3
# Cross Validation Accuracy = 96.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 4 , coef = 4
# Cross Validation Accuracy = 96.56%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 4 , coef = 5
# Cross Validation Accuracy = 96.78%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 5 , coef = 0
# Cross Validation Accuracy = 94.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 5 , coef = 1
# Cross Validation Accuracy = 95.08%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 5 , coef = 2
# Cross Validation Accuracy = 94.82%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 5 , coef = 3
# Cross Validation Accuracy = 95.1%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 5 , coef = 4
# Cross Validation Accuracy = 95.14%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 10 , degree = 5 , coef = 5
# Cross Validation Accuracy = 95.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 1 , coef = 0
# Cross Validation Accuracy = 96.5%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 1 , coef = 1
# Cross Validation Accuracy = 96.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 1 , coef = 2
# Cross Validation Accuracy = 96.7%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 1 , coef = 3
# Cross Validation Accuracy = 96.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 1 , coef = 4
# Cross Validation Accuracy = 97.02%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 1 , coef = 5
# Cross Validation Accuracy = 96.84%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 2 , coef = 0
# Cross Validation Accuracy = 97.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 2 , coef = 1
# Cross Validation Accuracy = 98.2%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 2 , coef = 2
# Cross Validation Accuracy = 97.96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 2 , coef = 3
# Cross Validation Accuracy = 98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 2 , coef = 4
# Cross Validation Accuracy = 98.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 2 , coef = 5
# Cross Validation Accuracy = 98.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 3 , coef = 0
# Cross Validation Accuracy = 97.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 3 , coef = 1
# Cross Validation Accuracy = 97.66%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 3 , coef = 2
# Cross Validation Accuracy = 97.62%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 3 , coef = 3
# Cross Validation Accuracy = 97.64%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 3 , coef = 4
# Cross Validation Accuracy = 97.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 3 , coef = 5
# Cross Validation Accuracy = 97.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 4 , coef = 0
# Cross Validation Accuracy = 96.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 4 , coef = 1
# Cross Validation Accuracy = 96.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 4 , coef = 2
# Cross Validation Accuracy = 96.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 4 , coef = 3
# Cross Validation Accuracy = 96.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 4 , coef = 4
# Cross Validation Accuracy = 96.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 4 , coef = 5
# Cross Validation Accuracy = 96.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 5 , coef = 0
# Cross Validation Accuracy = 94.8%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 5 , coef = 1
# Cross Validation Accuracy = 94.94%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 5 , coef = 2
# Cross Validation Accuracy = 94.76%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 5 , coef = 3
# Cross Validation Accuracy = 94.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 5 , coef = 4
# Cross Validation Accuracy = 95.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.001 , g = 100 , degree = 5 , coef = 5
# Cross Validation Accuracy = 94.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.01 , g = 0.001 , degree = 1 , coef = 0
# Cross Validation Accuracy = 79.26%
# ----------------------------------------------------------
# ...
# Cross Validation Accuracy = 98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 2 , coef = 4
# Cross Validation Accuracy = 98.2%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 2 , coef = 5
# Cross Validation Accuracy = 98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 3 , coef = 0
# Cross Validation Accuracy = 97.68%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 3 , coef = 1
# Cross Validation Accuracy = 97.76%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 3 , coef = 2
# Cross Validation Accuracy = 97.58%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 3 , coef = 3
# Cross Validation Accuracy = 97.76%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 3 , coef = 4
# Cross Validation Accuracy = 97.5%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 3 , coef = 5
# Cross Validation Accuracy = 97.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 4 , coef = 0
# Cross Validation Accuracy = 96.62%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 4 , coef = 1
# Cross Validation Accuracy = 96.6%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 4 , coef = 2
# Cross Validation Accuracy = 96.48%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 4 , coef = 3
# Cross Validation Accuracy = 96.5%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 4 , coef = 4
# Cross Validation Accuracy = 96.48%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 4 , coef = 5
# Cross Validation Accuracy = 96.58%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 5 , coef = 0
# Cross Validation Accuracy = 95.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 5 , coef = 1
# Cross Validation Accuracy = 95%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 5 , coef = 2
# Cross Validation Accuracy = 94.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 5 , coef = 3
# Cross Validation Accuracy = 94.88%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 5 , coef = 4
# Cross Validation Accuracy = 94.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 0.1 , g = 100 , degree = 5 , coef = 5
# Cross Validation Accuracy = 94.82%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 1 , coef = 0
# Cross Validation Accuracy = 95.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 1 , coef = 1
# Cross Validation Accuracy = 95.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 1 , coef = 2
# Cross Validation Accuracy = 95.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 1 , coef = 3
# Cross Validation Accuracy = 95.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 1 , coef = 4
# Cross Validation Accuracy = 95.4%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 1 , coef = 5
# Cross Validation Accuracy = 95.46%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 2 , coef = 0
# Cross Validation Accuracy = 80.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 2 , coef = 1
# Cross Validation Accuracy = 96.08%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 2 , coef = 2
# Cross Validation Accuracy = 96.48%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 2 , coef = 3
# Cross Validation Accuracy = 96.86%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 2 , coef = 4
# Cross Validation Accuracy = 96.96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 2 , coef = 5
# Cross Validation Accuracy = 96.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 3 , coef = 0
# Cross Validation Accuracy = 28.4%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 3 , coef = 1
# Cross Validation Accuracy = 96.32%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 3 , coef = 2
# Cross Validation Accuracy = 97.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 3 , coef = 3
# Cross Validation Accuracy = 97.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 3 , coef = 4
# Cross Validation Accuracy = 97.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 3 , coef = 5
# Cross Validation Accuracy = 97%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 4 , coef = 0
# Cross Validation Accuracy = 23.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 4 , coef = 1
# Cross Validation Accuracy = 96.78%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 4 , coef = 2
# Cross Validation Accuracy = 97.22%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 4 , coef = 3
# Cross Validation Accuracy = 97.08%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 4 , coef = 4
# Cross Validation Accuracy = 96.9%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 4 , coef = 5
# Cross Validation Accuracy = 96.82%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 5 , coef = 0
# Cross Validation Accuracy = 22.12%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 5 , coef = 1
# Cross Validation Accuracy = 96.96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 5 , coef = 2
# Cross Validation Accuracy = 97.3%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 5 , coef = 3
# Cross Validation Accuracy = 97%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 5 , coef = 4
# Cross Validation Accuracy = 96.78%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.001 , degree = 5 , coef = 5
# Cross Validation Accuracy = 96.52%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 0 , coef = 0
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 0 , coef = 1
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 0 , coef = 2
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 0 , coef = 3
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 0 , coef = 4
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 0 , coef = 5
# Cross Validation Accuracy = 20%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 1 , coef = 0
# Cross Validation Accuracy = 97.04%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 1 , coef = 1
# Cross Validation Accuracy = 97%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 1 , coef = 2
# Cross Validation Accuracy = 97.18%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 1 , coef = 3
# Cross Validation Accuracy = 96.98%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 1 , coef = 4
# Cross Validation Accuracy = 97.08%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 1 , coef = 5
# Cross Validation Accuracy = 96.96%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 2 , coef = 0
# Cross Validation Accuracy = 97.7%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 2 , coef = 1
# Cross Validation Accuracy = 97.54%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 2 , coef = 2
# Cross Validation Accuracy = 97.34%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 2 , coef = 3
# Cross Validation Accuracy = 97.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 2 , coef = 4
# Cross Validation Accuracy = 97.36%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 2 , coef = 5
# Cross Validation Accuracy = 97.32%
# ----------------------------------------------------------
# ----------------------------------------------------------
# Try the param with C = 1 , g = 0.01 , degree = 3 , coef = 0

# %%
RBF_best_C, RBF_best_g = grid_search_RBF(train_X, train_y)

# %%
RBF_kernel = '-t 2 '
svm_type = '-s 0 '
cost = f'-c {RBF_best_C} '
gamma = f'-g {RBF_best_g} '
best_param = svm_type + RBF_kernel + cost + gamma  + '-q'
print(f' best param of C : {RBF_best_C} , gamma : {RBF_best_g} ')

# %%
model = svm_train(train_y, train_X, best_param)
predict_y, predict_acc, predict_val = svm_predict(test_y, test_X, model, '-q')
print(f'Predict test data, accuracy : {predict_acc[0]} %')
